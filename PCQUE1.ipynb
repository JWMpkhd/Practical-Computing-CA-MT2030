# %% [markdown]
# ![Q1.png](attachment:Q1.png)

# %%
#Defining a fuction for volume of cuboid 
def VolumeofCuboid( l , b ,h  ):
    V=(l*b*h)
    return print("Volume of the rectangular cuboid is =" , V)

# %%
#Defining a fuction to find the area of the biggestest faces of the cuboid, which calculates the area of all possible faces and compares them to give the final value
def SAOBFOC( l , b , h ):
    A1= l * b

    A2= l * h

    A3= b * h

    if A1 > A2 :
        print("The maximum Face Area of a Cuboid =" ,A1)
    elif A2> A3:
        print("The maximum Face Area of a Cuboid =" ,A2)
    else :
        print( "The maximum Face Area of a Cuboid =", A3)
    return

# %%
#Taking the Input dimensions
l = float(input("Enter the Length of a Cuboid: "))
b = float(input("Enter the Width of a Cuboid: "))
h = float(input("Enter the Height of a Cuboid: "))
# Out:
# Enter the Length of a Cuboid: 30
# Enter the Width of a Cuboid: 20
# Enter the Height of a Cuboid: 15

# %%
VolumeofCuboid( l , b ,h  )
# Out:
# Volume of the rectangular cuboid is = 9000.0

# %%
SAOBFOC( l , b , h )
# Out:
# The maximum Face Area of a Cuboid = 600.0
